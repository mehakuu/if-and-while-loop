# %%
a=15
if(a>18):
    print("yes")

# %%
a=15
if(a<18):
    print("yes")
else:
    print("no")
print("This is not part if and else")
# Out:
# yes
# This is not part if and else

# %%
a= int(input("Enter the number"))
if(a<3):
    print("The value of a is lesser than 3")
elif(a>13):
    print("The value of a is greater than 13")
elif(a>7):
    print("The value of a is greater than 7")
elif(a>17):
    print("The value of a is greater than 17")
else:
    print("The value is not greater than 3 or 7")
# Out:
# Enter the number2
# The value of a is lesser than 3

# %%
age = int(input("Enter your age: "))
#if-else with the logical operator
if(age>34 or age<56):
    print("You can work with us")

else:
    print("You cannot work with us")
# Out:
# Enter your age: 40
# You can work with us

# %%
age = int(input("Enter your age: "))
#if-else with the logical operator
if(age>34 and age<56):
    print("You can work with us")

else:
    print("You cannot work with us")
# Out:
# Enter your age: 21
# You cannot work with us

# %%
a = [45, 56, 6]
print(45 in a)
print(48 in a)
# Out:
# True
# False

# %%
var= 15
if(var is 15):
    print("yes")
else:
    print("no")
# Out:
# yes
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-f9e06c37b787>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if(var is 15):

# %%
i = 0
while i<10:
    print("Yes " + str(i))
    i +=1 #i=i+1
print("Done")
# Out:
# Yes 0
# Yes 1
# Yes 2
# Yes 3
# Yes 4
# Yes 5
# Yes 6
# Yes 7
# Yes 8
# Yes 9
# Done

# %%
#print even number till 0 to 50
i=1
while i<51:
    if(i%2 == 0):
        print("YES " + str(i))
    i+=1
print("Done")
# Out:
# YES 2
# YES 4
# YES 6
# YES 8
# YES 10
# YES 12
# YES 14
# YES 16
# YES 18
# YES 20
# YES 22
# YES 24
# YES 26
# YES 28
# YES 30
# YES 32
# YES 34
# YES 36
# YES 38
# YES 40
# YES 42
# YES 44
# YES 46
# YES 48
# YES 50
# Done

# %%
fruits = ['Banana', 'Watermelon', 'Grapes', 'Mangoes']
i = 0
while i<len(fruits):
    print(fruits[i])
    i = i+1
# Out:
# Banana
# Watermelon
# Grapes
# Mangoes
